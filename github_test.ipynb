# %%
print('hi')
# Out:
# hi

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 2 sets of random data
data1 = np.random.rand(100)
data2 = np.random.rand(100)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(data1, label='Random Data 1')
plt.plot(data2, label='Random Data 2')
plt.title('Plot of Two Random Data Sets')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
